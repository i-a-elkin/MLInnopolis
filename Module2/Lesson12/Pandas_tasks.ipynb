# %% [markdown]
# # Работа с библиотекой Pandas

# %% [markdown]
# ## Загрузка модулей

# %%
import pandas as pd

# %% [markdown]
# ## Задача 1. Загрузить один из файлов csv в DataFrame

# %%
df = pd.read_csv("./JCMB_2015_May.csv")

# %% [markdown]
# ## Задача 2. Посмотреть на наименования столбцов. При необходимости, сократить или сделать более понятными

# %%
old_columns = df.columns

old_columns
# Out:
# Index(['date-time', 'atmospheric pressure (mBar)', 'rainfall (mm)',
#        'wind speed (m/s)', 'wind direction (degrees)',
#        'surface temperature (C)', 'relative humidity (%)',
#        'solar flux (Kw/m2)', 'battery (V)'],
#       dtype='object')

# %% [markdown]
# Сократим названия столбцов.

# %%
new_columns = [
    "date_time",
    "pressure",
    "rainfall",
    "wind_speed",
    "wind_direction",
    "temperature",
    "humidity",
    "solar_flux",
    "battery",
]
df.columns = new_columns

df.columns
# Out:
# Index(['date_time', 'pressure', 'rainfall', 'wind_speed', 'wind_direction',
#        'temperature', 'humidity', 'solar_flux', 'battery'],
#       dtype='object')

# %% [markdown]
# ## Задача 3. Сохранить первые 1000 строк DataFrame в CSV-файл

# %%
df[:1000].to_csv("./JCMB_2015_May_sample.csv", index=False)

# %% [markdown]
# ## Задача 4. Загрузите в DataFrame сохраненный на предыдущем шаге CSV-файл и отобразите на экране первые 20 записей, последние 20 записей, любой срез по записям

# %%
df_sample = pd.read_csv("./JCMB_2015_May_sample.csv")

# %% [markdown]
# Первые 20 записей.

# %%
df_sample.head(20)
# Out:
#            date_time  pressure  rainfall  wind_speed  wind_direction  \
# 0   2015/05/01 00:01      1014       0.0         0.0             0.0
# 1   2015/05/01 00:02      1014       0.0         0.0             0.0
# 2   2015/05/01 00:03      1014       0.0         0.0             0.0
# 3   2015/05/01 00:04      1014       0.0         0.0             0.0
# 4   2015/05/01 00:05      1014       0.0         0.0             0.0
# 5   2015/05/01 00:06      1014       0.0         0.0             0.0
# 6   2015/05/01 00:07      1014       0.0         0.0             0.0
# 7   2015/05/01 00:08      1014       0.0         0.0             0.0
# 8   2015/05/01 00:09      1014       0.0         0.0             0.0
# 9   2015/05/01 00:10      1014       0.0         0.0             0.0
# 10  2015/05/01 00:11      1014       0.0         0.0             0.0
# 11  2015/05/01 00:12      1014       0.0         0.0             0.0
# 12  2015/05/01 00:13      1014       0.0         0.0             0.0
# 13  2015/05/01 00:14      1014       0.0         0.0             0.0
# 14  2015/05/01 00:15      1014       0.0         0.0             0.0
# 15  2015/05/01 00:16      1014       0.0         0.0             0.0
# 16  2015/05/01 00:17      1014       0.0         0.0             0.0
# 17  2015/05/01 00:18      1014       0.0         0.0             0.0
# 18  2015/05/01 00:19      1014       0.0         0.0             0.0
# 19  2015/05/01 00:20      1014       0.0         0.0             0.0
#
#     temperature  humidity  solar_flux  battery
# 0         4.565      79.5         0.0    13.89
# 1         4.543      79.4         0.0    13.89
# 2         4.494      79.3         0.0    13.89
# 3         4.472      79.3         0.0    13.89
# 4         4.453      79.4         0.0    13.89
# 5         4.436      79.4         0.0    13.89
# 6         4.425      79.4         0.0    13.89
# 7         4.376      79.3         0.0    13.89
# 8         4.327      79.3         0.0    13.89
# 9         4.288      79.4         0.0    13.89
# 10        4.269      79.5         0.0    13.89
# 11        4.258      79.6         0.0    13.89
# 12        4.264      79.8         0.0    13.89
# 13        4.280      79.9         0.0    13.89
# 14        4.280      80.0         0.0    13.89
# 15        4.294      80.1         0.0    13.89
# 16        4.324      80.2         0.0    13.89
# 17        4.327      80.2         0.0    13.89
# 18        4.313      80.1         0.0    13.89
# 19        4.280      80.0         0.0    13.89

# %% [markdown]
# Последние 20 записей.

# %%
df_sample.tail(20)
# Out:
#             date_time  pressure  rainfall  wind_speed  wind_direction  \
# 980  2015/05/01 16:21      1013       0.0       1.750           42.21
# 981  2015/05/01 16:22      1013       0.0       1.792           76.60
# 982  2015/05/01 16:23      1013       0.0       2.229           30.73
# 983  2015/05/01 16:24      1013       0.0       3.167           56.83
# 984  2015/05/01 16:25      1013       0.0       2.521           45.30
# 985  2015/05/01 16:26      1013       0.0       2.500           67.09
# 986  2015/05/01 16:27      1013       0.0       2.458           53.44
# 987  2015/05/01 16:28      1013       0.0       1.771           67.05
# 988  2015/05/01 16:29      1013       0.0       2.688           59.57
# 989  2015/05/01 16:30      1013       0.0       3.063           79.10
# 990  2015/05/01 16:31      1013       0.0       1.438           66.25
# 991  2015/05/01 16:32      1013       0.0       1.958           38.84
# 992  2015/05/01 16:33      1013       0.0       3.396           61.41
# 993  2015/05/01 16:34      1013       0.0       2.125           61.42
# 994  2015/05/01 16:35      1013       0.0       1.563           51.54
# 995  2015/05/01 16:36      1013       0.0       3.604           42.71
# 996  2015/05/01 16:37      1013       0.0       3.500           39.52
# 997  2015/05/01 16:38      1013       0.0       3.083           44.23
# 998  2015/05/01 16:39      1013       0.0       1.792           64.90
# 999  2015/05/01 16:40      1013       0.0       2.125           42.44
#
#      temperature  humidity  solar_flux  battery
# 980         7.53     61.70    0.483895    13.55
# 981         7.68     61.50    0.498693    13.54
# 982         7.79     60.91    0.516450    13.55
# 983         7.60     61.40    0.512011    13.55
# 984         7.45     62.03    0.506092    13.55
# 985         7.58     61.11    0.494253    13.55
# 986         7.43     61.64    0.504612    13.55
# 987         7.50     61.90    0.512011    13.55
# 988         7.58     61.44    0.537167    13.55
# 989         7.39     61.97    0.543087    13.55
# 990         7.46     62.23    0.557885    13.55
# 991         7.61     61.74    0.550486    13.55
# 992         7.35     62.82    0.498693    13.55
# 993         7.24     63.41    0.409905    13.55
# 994         7.38     62.43    0.517930    13.56
# 995         7.31     62.69    0.531248    13.55
# 996         7.18     62.95    0.546046    13.55
# 997         7.15     63.61    0.554925    13.56
# 998         7.32     62.88    0.568243    13.56
# 999         7.40     62.62    0.583041    13.56

# %% [markdown]
# Срез по данным.

# %%
df_sample.loc[::100, ["date_time", "wind_speed", "humidity"]]
# Out:
#             date_time  wind_speed  humidity
# 0    2015/05/01 00:01       0.000     79.50
# 100  2015/05/01 01:41       0.708     69.03
# 200  2015/05/01 03:21       0.000     65.89
# 300  2015/05/01 05:01       0.000     70.10
# 400  2015/05/01 06:41       0.000     71.90
# 500  2015/05/01 08:21       0.354     65.30
# 600  2015/05/01 10:01       0.000     57.30
# 700  2015/05/01 11:41       1.646     59.42
# 800  2015/05/01 13:21       2.854     54.49
# 900  2015/05/01 15:01       3.854     60.53

# %% [markdown]
# ## Задача 5. Найдите количество уникальных значений столбца «relativehumidity(%)» (или % для данных старше 2017 года) и отобразите их на экране

# %%
humidity_unique_sample = df_sample["humidity"].unique()

print(
    f"Количество уникальных значений столбца «relative humidity (%): {humidity_unique_sample.shape[0]}"
)
humidity_unique_sample
# Out:
# Количество уникальных значений столбца «relative humidity (%): 521
# array([79.5 , 79.4 , 79.3 , 79.6 , 79.8 , 79.9 , 80.  , 80.1 , 80.2 ,
#        80.3 , 80.5 , 80.4 , 79.7 , 79.1 , 79.  , 78.9 , 78.8 , 78.6 ,
#        78.5 , 78.2 , 78.  , 77.6 , 77.4 , 77.1 , 76.7 , 76.4 , 76.1 ,
#        75.4 , 75.  , 74.3 , 74.  , 73.6 , 72.9 , 72.6 , 72.1 , 71.7 ,
#        72.  , 71.8 , 71.9 , 71.6 , 71.3 , 70.4 , 69.88, 69.29, 69.1 ,
#        68.67, 68.64, 68.7 , 68.83, 69.23, 68.9 , 69.  , 68.96, 69.03,
#        69.33, 69.36, 69.42, 69.49, 69.56, 69.69, 69.62, 69.26, 69.19,
#        69.16, 68.51, 68.31, 68.24, 67.98, 67.85, 67.65, 67.46, 67.13,
#        66.67, 66.47, 66.21, 65.88, 65.75, 66.08, 66.14, 66.01, 65.65,
#        65.78, 65.92, 66.31, 66.54, 66.8 , 67.  , 67.26, 67.39, 67.33,
#        67.17, 67.1 , 67.36, 66.51, 66.25, 65.76, 65.63, 65.49, 65.46,
#        65.72, 65.82, 65.95, 66.15, 65.86, 65.56, 65.66, 65.69, 65.89,
#        66.09, 66.22, 66.28, 66.02, 64.97, 64.64, 64.61, 64.67, 64.74,
#        64.77, 64.81, 64.9 , 65.07, 65.1 , 65.4 , 66.81, 67.47, 67.63,
#        67.79, 67.93, 68.12, 68.19, 68.22, 68.38, 68.42, 68.06, 68.35,
#        68.58, 68.65, 68.84, 69.01, 69.24, 69.3 , 69.44, 69.5 , 69.57,
#        69.63, 69.83, 69.93, 69.96, 70.  , 70.1 , 70.2 , 70.3 , 70.6 ,
#        70.5 , 69.89, 69.76, 69.4 , 69.37, 70.7 , 70.9 , 71.4 , 71.1 ,
#        71.  , 70.8 , 71.2 , 71.5 , 72.2 , 69.53, 68.91, 68.94, 68.52,
#        68.25, 68.45, 68.78, 68.98, 69.04, 69.27, 69.34, 69.14, 69.17,
#        68.02, 67.73, 67.37, 67.27, 67.66, 67.01, 66.61, 66.94, 66.55,
#        66.32, 66.48, 66.38, 66.05, 65.99, 65.3 , 65.43, 65.5 , 64.71,
#        64.51, 64.87, 64.58, 63.85, 64.11, 64.25, 64.18, 64.01, 64.41,
#        63.78, 63.98, 63.81, 63.58, 63.52, 63.65, 63.19, 62.89, 62.6 ,
#        62.79, 62.86, 62.63, 63.09, 62.47, 62.56, 62.53, 62.66, 62.93,
